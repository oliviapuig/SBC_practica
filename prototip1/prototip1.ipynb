# %% [markdown]
# # SBC - Pràctica CBR
#
# - Aina Gomila
# - Ruth Parajó
# - Olivia Puig
# - Marc Ucelayeta

# %%
from cbr import CBR
import pandas as pd

# %%
casos = pd.read_csv('casos.csv')

# %%
nou_cas ={
    'estils_literaris': 'Escola Mallorquina',
    'temes_de_llibres': 'Filosofia',
    'complexitat': 'Mitja',
    'demografia': 'Adult',
    'situacio': 'Treballador',
    'estat_civil': 'Solter',
    "llibres_recomanats": [],
    "puntuacio_llibres": []
}

# %%
for index,fila in casos.iterrows():
    print('ee',fila['estils_literaris'])
    print(fila,'\n')
# Out:
# ee Escola Mallorquina
# estils_literaris                                     Escola Mallorquina
# temes_de_llibres                                                Comèdia
# complexitat                                                       mitja
# demografia                                                        adult
# situacio                                                      estudiant
# estat_civil                                                       viudu
# llibres_recomanats    ['Baseball: a Literary Anthology', 'Patrimony'...
# puntuacio_llibres                                             [5, 3, 2]
# Name: 0, dtype: object
#
# ee Escola Mallorquina
# estils_literaris                                     Escola Mallorquina
# temes_de_llibres                                              Culinària
# complexitat                                                       baixa
# demografia                                                     infantil
# ...

# %%
cbr = CBR(casos)
user_final = cbr.recomana(nou_cas)
print(user_final)
cbr.users
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/ruthparajo/Desktop/uni/SBC/pràctica 2/SBC_practica/prototip1/prototip1.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/Users/ruthparajo/Desktop/uni/SBC/pra%CC%80ctica%202/SBC_practica/prototip1/prototip1.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> cbr = CBR(casos)
#       <a href='vscode-notebook-cell:/Users/ruthparajo/Desktop/uni/SBC/pra%CC%80ctica%202/SBC_practica/prototip1/prototip1.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> user_final = cbr.recomana(nou_cas)
#       <a href='vscode-notebook-cell:/Users/ruthparajo/Desktop/uni/SBC/pra%CC%80ctica%202/SBC_practica/prototip1/prototip1.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> print(user_final)
#
# File ~/Desktop/uni/SBC/pràctica 2/SBC_practica/prototip1/cbr.py:11, in CBR.__init__(self, users)
# ...
