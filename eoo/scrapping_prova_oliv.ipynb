# %%
import requests
import pandas as pd

# agafem el dataframe llibres.csv 
llibres = pd.read_csv('llibres.csv', sep=',')
llibres.head()
# Out:
#          isbn   book_id                                      similar_books  \
# 0  0800759494     89375  ['299795', '8100288', '7570892', '53817', '121...
# 1  0842379428     89376  ['45366', '246849', '11096385', '19102466', '7...
# 2  1503945650  25317381  ['23992482', '21995039', '16065476', '23006790...
# 3         NaN  26864719  ['25653691', '18106800', '29566096', '26547917...
# 4         NaN  12077902  ['2108205', '331256', '553907', '1451628', '14...
#
#    average_rating                                        description  \
# 0            3.91  As he is driving home from a minister's confer...
# 1            4.26  What is Heaven really going to be like? What w...
# 2            3.69  An Amazon Best Book of the Year\nA Goodreads B...
# 3            3.65  He wanted a baby. I needed a man.\nFaith\nThe ...
# 4            3.98  A classic work of science fiction by renowned ...
#
#                           authors         isbn13  num_pages  publication_year  \
# ...

# %%
#
